# %%
#Python sebagai Kalkulator

# %%
1+3
# Out:
# 4

# %%
(9/3)*5+7
# Out:
# 22.0

# %%
import math

# %%
math.sqrt(36)
# Out:
# 6.0

# %%
math
# Out:
# <module 'math' from '/Users/siskaarif/anaconda3/lib/python3.11/lib-dynload/math.cpython-311-darwin.so'>

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %%
type(1234)
# Out:
# int

# %%
type(1.245)
# Out:
# float

# %%
6 == 8
# Out:
# False

# %%
8 == 8
# Out:
# True

# %%
9 != 8
# Out:
# True

# %%
9 < 7
# Out:
# False

# %%
print("I love python")
# Out:
# I love python

# %%
math.sqrt(pow(5-3,2)+pow(9-4,2))
# Out:
# 5.385164807134504

# %%
"don\'t"
# Out:
# "don't"

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x): return np.sin(5*x) + np.cos(2*x)

x1 = np.arange(-1,1,0.01)
plt.plot(x1,f(x1))
plt.xlabel('x'); plt.ylabel('f')
plt.grid(); plt.show()

print("f(-0.525):",f(-0.525)) 
print("f(-0.21):",f(-0.21)) 
print("f(0.675):",f(0.675)) 

x2 = np.arange(-0.53, -0.52,0.01)
plt.plot(x2,f(x2))
plt.xlabel('x'); plt.ylabel('f')
plt.grid(); plt.show()

x3 = np.arange(-0.25, -0.2,0.01)
plt.plot(x3,f(x3))
plt.xlabel('x'); plt.ylabel('f')
plt.grid(); plt.show()

x4 = np.arange(0.66, 0.675,0.01)
plt.plot(x4,f(x4))
plt.xlabel('x'); plt.ylabel('f')
plt.grid(); plt.show()

print("f(-0.5235):",f(-0.5235)) 
print("f(-0.225):",f(-0.225)) 
print("f(0.6731):",f( 0.6731))
# Out:
# f(-0.525): 0.0036507492816377773
# f(-0.21): 0.045665714718291284
# f(0.675): -0.012287125308980323
# f(-0.5235): -0.00025657529368039445
# f(-0.225): -0.0018204917464182957
# f(0.6731): 0.0006717288222329032

# %%
def f(x): return pow(x,3)+pow(x,2)-34*x+56

x1 = np.arange(1,5,0.4)
plt.plot(x1,f(x1))
plt.xlabel('x'); plt.ylabel('f')
plt.grid(); plt.show()

print("f(1):",f(1)) 
print("f(1.4):",f(1.4)) 
print("f(1.8):",f(1.8)) 
print("f(2.2):",f(2.2)) 
print("f(2.6):",f(2.6)) 
print("f(3):",f(3)) 
print("f(3.4):",f(3.4)) 
print("f(3.8):",f(3.8))
print("f(4.2):",f(4.2))
# Out:
# f(1): 24
# f(1.4): 13.104000000000006
# f(1.8): 3.872
# f(2.2): -3.312000000000012
# f(2.6): -8.064000000000007
# f(3): -10
# f(3.4): -8.736000000000004
# f(3.8): -3.887999999999991
# f(4.2): 4.927999999999997
